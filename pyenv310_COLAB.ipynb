# %% [markdown]
# <a href="https://colab.research.google.com/github/lmolinario/ML_Sec_project/blob/main/pyenv310_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.10 python3.10-venv python3.10-distutils
# !python3.10 -m venv py310_env
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,306 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,650 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,604 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !source py310_env/bin/activate

# %%
# !py310_env/bin/python -m pip install --upgrade pip
# !py310_env/bin/python -m pip install git+https://github.com/RobustBench/robustbench
# !py310_env/bin/python -m pip install secml foolbox torch numpy matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# ...
#   Cloning https://github.com/RobustBench/robustbench to /tmp/pip-req-build-ptdd83rd
#   Running command git clone --filter=blob:none --quiet https://github.com/RobustBench/robustbench /tmp/pip-req-build-ptdd83rd
#   Resolved https://github.com/RobustBench/robustbench to commit 46a91f44524133b2cd8f721ec7e73ecb63f17fc8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/fra31/auto-attack.git (to revision a39220048b3c9f2cca9a4d3a54604793c68eca7e) to /tmp/pip-install-n6n2_16h/autoattack_547041bcba0c45bba16d730aa8164636
# ...

# %%
# !py310_env/bin/python --version  # Verifica che stai usando Python 3.10
# Out:
# Python 3.10.12

# %%
# !py310_env/bin/pip uninstall -y numpy
# Out:
# Found existing installation: numpy 2.2.2
# Uninstalling numpy-2.2.2:
#   Successfully uninstalled numpy-2.2.2

# %%
# !py310_env/bin/pip install numpy==1.23.5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 103.0 MB/s eta 0:00:00
# ...

# %%
# !py310_env/bin/pip show numpy
# Out:
# Name: numpy
# Version: 1.23.5
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /content/py310_env/lib/python3.10/site-packages
# Requires:
# Required-by: contourpy, eagerpy, foolbox, matplotlib, pandas, robustbench, scikit-learn, scipy, secml, torchvision

# %%
# !py310_env/bin/pip install  ipykernel
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 75.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.5/825.5 kB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.2/874.2 kB 49.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.1 MB/s eta 0:00:00
# ...

# %%
# !pip install gdown

# %%
import gdown
import os

# Lista di file ID e i loro nomi originali
files = {
    "18_Zl5Zkje4kIk7KwddYu04bY4zDPl12G": "virtenvFNM4COLAB.py",
    "1WN52O9mxx0qowMMC8wgKTwxVX8ywm8CK": "data_attack_result_FMN.pkl",
    "1EdxnaSay0BLe5JJ553L3lrZP1Jryya94": "data_attack_result_FMN_CONFIDENCE.pkl",
    "1fBtfw-USkZBMV67K6nYfw2idtizJYBmP": "data_attack_result_AA.pkl"
}

# Cartella di destinazione
output_dir = "/content/"

# Scaricare tutti i file con il loro nome originale
for file_id, file_name in files.items():
    url = f"https://drive.google.com/uc?id={file_id}"
    output_path = os.path.join(output_dir, file_name)
    gdown.download(url, output_path, quiet=False)

print("✅ Download completato!")
import os

# Specifica il percorso della cartella
folder_path = "/content/results"

# Crea la cartella se non esiste già
os.makedirs(folder_path, exist_ok=True)

print(f"✅ Cartella '{folder_path}' creata con successo!")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1DTb3g1yyr8jnCdK_eFt-eQBB9yL6ZYgy
# From (redirected): https://drive.google.com/uc?id=1DTb3g1yyr8jnCdK_eFt-eQBB9yL6ZYgy&confirm=t&uuid=e2c1285d-7080-4603-902f-a881d948b6f5
# To: /content/virtenvFNM4COLAB.py
# 100%|██████████| 47.2k/47.2k [00:00<00:00, 72.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1WN52O9mxx0qowMMC8wgKTwxVX8ywm8CK
# From (redirected): https://drive.google.com/uc?id=1WN52O9mxx0qowMMC8wgKTwxVX8ywm8CK&confirm=t&uuid=e9a43462-644f-472f-9068-514a715afdfd
# To: /content/data_attack_result_FMN.pkl
# 100%|██████████| 148M/148M [00:00<00:00, 240MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1EdxnaSay0BLe5JJ553L3lrZP1Jryya94
# From (redirected): https://drive.google.com/uc?id=1EdxnaSay0BLe5JJ553L3lrZP1Jryya94&confirm=t&uuid=981cb6f9-9768-4135-b791-c18a6288536c
# To: /content/data_attack_result_FMN_CONFIDENCE.pkl
# ...

# %%
# !py310_env/bin/python /content/virtenvFNM4COLAB.py
# Out:
# RobustBench version: robustbench
# SecML version: 0.15.6
# Foolbox version: 3.3.4
# Numpy version: 1.23.5
#
# Loading CIFAR-10 dataset...
#
# Computing model accuracy on clean data...
#
# Verifying model loading:
# ------------------------------------------------------------------------------------------
# Model Ding2020MMA loaded successfully.
# Model Wong2020Fast loaded successfully.
# Model Andriushchenko2020Understanding loaded successfully.
# Model Sitawarin2020Improving loaded successfully.
# Model Cui2023Decoupled_WRN-28-10 loaded successfully.
# ------------------------------------------------------------------------------------------
#
# Model accuracy on clean data:
# ------------------------------------------------------------------------------------------
# Model name: Ding2020MMA                              - Clean model accuracy: 84.38 %
# Model name: Wong2020Fast                             - Clean model accuracy: 84.38 %
# ...
