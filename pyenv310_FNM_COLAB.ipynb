# %% [markdown]
# <a href="https://colab.research.google.com/github/lmolinario/ML_Sec_project/blob/main/pyenv310_FNM_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.10 python3.10-venv python3.10-distutils
# !python3.10 -m venv py310_env
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,304 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,650 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !source py310_env/bin/activate

# %%
# !py310_env/bin/python -m pip install --upgrade pip
# !py310_env/bin/python -m pip install git+https://github.com/RobustBench/robustbench
# !py310_env/bin/python -m pip install secml foolbox torch numpy matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# ...
#   Cloning https://github.com/RobustBench/robustbench to /tmp/pip-req-build-mjwj25sj
#   Running command git clone --filter=blob:none --quiet https://github.com/RobustBench/robustbench /tmp/pip-req-build-mjwj25sj
#   Resolved https://github.com/RobustBench/robustbench to commit 46a91f44524133b2cd8f721ec7e73ecb63f17fc8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/fra31/auto-attack.git (to revision a39220048b3c9f2cca9a4d3a54604793c68eca7e) to /tmp/pip-install-usqpr2gw/autoattack_711a0b10137c4d2e8ae8c46dbae56254
# ...

# %%
# !py310_env/bin/python --version  # Verifica che stai usando Python 3.10
# Out:
# Python 3.10.12

# %%
# !py310_env/bin/pip uninstall -y numpy
# Out:
# Found existing installation: numpy 2.2.2
# Uninstalling numpy-2.2.2:
#   Successfully uninstalled numpy-2.2.2

# %%
# !py310_env/bin/pip install numpy==1.23.5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 76.5 MB/s eta 0:00:00
# ...

# %%
# !py310_env/bin/pip show numpy
# Out:
# Name: numpy
# Version: 1.23.5
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /content/py310_env/lib/python3.10/site-packages
# Requires:
# Required-by: contourpy, eagerpy, foolbox, matplotlib, pandas, robustbench, scikit-learn, scipy, secml, torchvision

# %%
# !py310_env/bin/pip install  ipykernel
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 75.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 40.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.2/874.2 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.6 MB/s eta 0:00:00
# ...

# %%
#!py310_env/bin/python /content/virtenvFNM.py
# !py310_env/bin/python /content/virtenvFNM4COLABconAA.py
# Out:
# 2025-01-30 21:57:20,177 - secml.settings - INFO - New `SECML_HOME_DIR` created: /root/secml-data
# 2025-01-30 21:57:20,177 - secml.settings - INFO - New `SECML_HOME_DIR` created: /root/secml-data
# 2025-01-30 21:57:20,177 - secml.settings - INFO - Default configuration file copied to: /root/secml-data/secml.conf
# 2025-01-30 21:57:20,177 - secml.settings - INFO - Default configuration file copied to: /root/secml-data/secml.conf
# 2025-01-30 21:57:20,178 - secml.settings - INFO - New `SECML_DS_DIR` created: /root/secml-data/datasets
# 2025-01-30 21:57:20,178 - secml.settings - INFO - New `SECML_DS_DIR` created: /root/secml-data/datasets
# 2025-01-30 21:57:20,179 - secml.settings - INFO - New `SECML_MODELS_DIR` created: /root/secml-data/models
# 2025-01-30 21:57:20,179 - secml.settings - INFO - New `SECML_MODELS_DIR` created: /root/secml-data/models
# 2025-01-30 21:57:20,180 - secml.settings - INFO - New `SECML_EXP_DIR` created: /root/secml-data/experiments
# ...
